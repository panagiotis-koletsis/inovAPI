# %%
# import requests

# url = "http://127.0.0.1:8000/upload"

# # Choose a file on your machine
# file_path = "test.txt"  # change this to any file you want to upload

# with open(file_path, "rb") as f:
#     files = {"file": (file_path, f)}
#     response = requests.post(url, files=files)

# print("Status:", response.status_code)
# print("Response:", response.json())
# Out:
# Status: 422
# Response: {'detail': [{'type': 'missing', 'loc': ['body', 'files'], 'msg': 'Field required', 'input': None}]}

# %%
import requests

url = "http://127.0.0.1:8000/upload"

files = [
    ("files", ("test.txt", open("test.txt", "rb"))),
    ("files", ("test1.txt", open("test1.txt", "rb")))
]

response = requests.post(url, files=files)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'uploaded_files': ['test.txt', 'test1.txt']}

# %%
import requests

url = "http://127.0.0.1:8000/getResults"

response = requests.get(url)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'test_extracted': {'entityTypes': ['--NME--'], 'entityNames': ['Tesla', 'SpaceX', 'Elon Musk'], 'entityRels': ['Tesla --[company]--> SpaceX']}, 'test1_extracted': {'entityTypes': ['--NME--'], 'entityNames': ['Blue Origin', 'Amazon', 'Jeff Bezos'], 'entityRels': ['Amazon --[shareholders]--> Jeff Bezos', 'Jeff Bezos --[shareholder of]--> Amazon', 'Jeff Bezos --[company]--> Amazon', 'Amazon --[founded by]--> Jeff Bezos']}}

# %%
import requests

url = "http://127.0.0.1:8000/getAllRelationTypes"

response = requests.get(url)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'relationTypes': ['rel1', 'rel2']}

# %%
import requests

url = "http://127.0.0.1:8000/getAllEntityTypes"

response = requests.get(url)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'entityTypes': ['ent1', 'ent2']}
